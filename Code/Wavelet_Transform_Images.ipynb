# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt
import pywt.data

# %%
plt.imshow(original,  interpolation="nearest", cmap=plt.cm.gray)
plt.savefig('original_image.png')

# %%
# Load image
original = pywt.data.camera()

# Wavelet transform of image, and plot approximation and details
titles = ['Approximation(Low-Low)', ' Detail(Low-High)',
          'Detail(High-Low)', 'Detail(High-High)']
coeffs2 = pywt.dwt2(original, 'haar')
LL, (LH, HL, HH) = coeffs2
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()
fig.savefig('first_order_DWT_example.png')

# %%
coeffs3 = pywt.dwt2(LL, 'haar')

# %%
LL, (LH, HL, HH) = coeffs3
fig = plt.figure(figsize=(12, 3))
for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()

fig.savefig('second_order_DWT_example.png')

# %%
image = original
titles = ['Approximation(Low-Low)', ' Detail(Low-High)',
          'Detail(High-Low)', 'Detail(High-High)']
for i in range(10):
    coeffs = pywt.dwt2(image, 'db2')
    LL, (LH, HL, HH) = coeffs
    fig = plt.figure(figsize=(12, 3))
    for i, a in enumerate([LL, LH, HL, HH]):
        ax = fig.add_subplot(1, 4, i + 1)
        ax.imshow(a, interpolation="nearest", cmap=plt.cm.gray)
        ax.set_title(titles[i], fontsize=10)
        ax.set_xticks([])
        ax.set_yticks([])

    fig.tight_layout()
    plt.show()
    image = LL
